# %%
import pandas as pd
data = pd.read_csv("2B_HeartDis.txt",sep=',')
data
# Out:
#      age  sex  cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   4   140.0  260.0  0.0        1     112.0   1.0      3.0  2.0
# 1     44    1   4   130.0  209.0  0.0        1     127.0   0.0      0.0  NaN
# 2     60    1   4   132.0  218.0  0.0        1     140.0   1.0      1.5  3.0
# 3     55    1   4   142.0  228.0  0.0        1     149.0   1.0      2.5  1.0
# 4     66    1   3   110.0  213.0  1.0        2      99.0   1.0      1.3  2.0
# ..   ...  ...  ..     ...    ...  ...      ...       ...   ...      ...  ...
# 195   54    0   4   127.0  333.0  1.0        1     154.0   0.0      0.0  NaN
# 196   62    1   1     NaN  139.0  0.0        1       NaN   NaN      NaN  NaN
# 197   55    1   4   122.0  223.0  1.0        1     100.0   0.0      0.0  NaN
# 198   58    1   4     NaN  385.0  1.0        2       NaN   NaN      NaN  NaN
# 199   62    1   2   120.0  254.0  0.0        2      93.0   1.0      0.0  NaN
#
#      caa  thall  output
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   4   140.0  260.0  0.0        1     112.0   1.0      3.0  2.0
# 1   44    1   4   130.0  209.0  0.0        1     127.0   0.0      0.0  NaN
# 2   60    1   4   132.0  218.0  0.0        1     140.0   1.0      1.5  3.0
# 3   55    1   4   142.0  228.0  0.0        1     149.0   1.0      2.5  1.0
# 4   66    1   3   110.0  213.0  1.0        2      99.0   1.0      1.3  2.0
#
#    caa  thall  output
# 0  2.0    2.0       2
# 1  NaN    NaN       0
# 2  NaN    NaN       2
# 3  NaN    NaN       1
# 4  NaN    NaN       0

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       200 non-null    int64
#  1   sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trtbps    144 non-null    float64
#  4   chol      193 non-null    float64
#  5   fbs       193 non-null    float64
#  6   restecg   200 non-null    int64
#  7   thalachh  147 non-null    float64
#  8   exng      147 non-null    float64
#  9   oldpeak   144 non-null    float64
#  10  slp       99 non-null     float64
#  11  caa       4 non-null      float64
#  12  thall     42 non-null     float64
#  13  output    200 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 22.0 KB

# %%
data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  200.000000  200.000000  200.000000  144.000000  193.000000  193.000000
# mean    59.350000    0.970000    3.505000  133.763889  178.746114    0.352332
# std      7.811697    0.171015    0.795701   21.537733  114.035232    0.478939
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  216.000000    0.000000
# 75%     64.000000    1.000000    4.000000  147.000000  258.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak        slp       caa  \
# count  200.000000  147.000000  147.000000  144.000000  99.000000  4.000000
# mean     0.735000  122.795918    0.646259    1.320833   2.111111  1.750000
# ...

# %%
data=data.drop_duplicates()

# %%
data.isna().sum()
# Out:
# age           0
# sex           0
# cp            0
# trtbps       56
# chol          7
# fbs           7
# restecg       0
# thalachh     53
# exng         53
# oldpeak      56
# slp         100
# caa         195
# thall       157
# output        0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trtbps       56
# chol          7
# fbs           7
# restecg       0
# thalachh     53
# exng         53
# oldpeak      56
# slp         100
# caa         195
# thall       157
# output        0
# dtype: int64

# %%
data = data.fillna(0)

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
data1=data[['age','cp','chol','slp']]

# %%
data2=data[['sex','fbs','caa','output']]

# %%
import pandas as pd
merged_data = pd.merge(data1, data2, left_index=True, right_index=True)

# %%
data1
# Out:
#      age  cp   chol  slp
# 0     63   4  260.0  2.0
# 1     44   4  209.0  0.0
# 2     60   4  218.0  3.0
# 3     55   4  228.0  1.0
# 4     66   3  213.0  2.0
# ..   ...  ..    ...  ...
# 195   54   4  333.0  0.0
# 196   62   1  139.0  0.0
# 197   55   4  223.0  0.0
# 198   58   4  385.0  0.0
# 199   62   2  254.0  0.0
#
# [199 rows x 4 columns]

# %%
data2
# Out:
#      sex  fbs  caa  output
# 0      1  0.0  2.0       2
# 1      1  0.0  0.0       0
# 2      1  0.0  0.0       2
# 3      1  0.0  0.0       1
# 4      1  1.0  0.0       0
# ..   ...  ...  ...     ...
# 195    0  1.0  0.0       1
# 196    1  0.0  0.0       0
# 197    1  1.0  0.0       2
# 198    1  1.0  0.0       0
# 199    1  0.0  0.0       1
#
# [199 rows x 4 columns]

# %%
merged_data
# Out:
#      age  cp   chol  slp  sex  fbs  caa  output
# 0     63   4  260.0  2.0    1  0.0  2.0       2
# 1     44   4  209.0  0.0    1  0.0  0.0       0
# 2     60   4  218.0  3.0    1  0.0  0.0       2
# 3     55   4  228.0  1.0    1  0.0  0.0       1
# 4     66   3  213.0  2.0    1  1.0  0.0       0
# ..   ...  ..    ...  ...  ...  ...  ...     ...
# 195   54   4  333.0  0.0    0  1.0  0.0       1
# 196   62   1  139.0  0.0    1  0.0  0.0       0
# 197   55   4  223.0  0.0    1  1.0  0.0       2
# 198   58   4  385.0  0.0    1  1.0  0.0       0
# 199   62   2  254.0  0.0    1  0.0  0.0       1
#
# [199 rows x 8 columns]

# %%
data_concat = pd.concat([data1, data2], axis=1)
data_concat
# Out:
#      age  cp   chol  slp  sex  fbs  caa  output
# 0     63   4  260.0  2.0    1  0.0  2.0       2
# 1     44   4  209.0  0.0    1  0.0  0.0       0
# 2     60   4  218.0  3.0    1  0.0  0.0       2
# 3     55   4  228.0  1.0    1  0.0  0.0       1
# 4     66   3  213.0  2.0    1  1.0  0.0       0
# ..   ...  ..    ...  ...  ...  ...  ...     ...
# 195   54   4  333.0  0.0    0  1.0  0.0       1
# 196   62   1  139.0  0.0    1  0.0  0.0       0
# 197   55   4  223.0  0.0    1  1.0  0.0       2
# 198   58   4  385.0  0.0    1  1.0  0.0       0
# 199   62   2  254.0  0.0    1  0.0  0.0       1
#
# [199 rows x 8 columns]

# %%
df=pd.read_csv("heart.csv")
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
import numpy as np
df['age_square'] = np.square(df['age'])
df['age_cube'] = np.power(df['age'], 3)
df['age_log'] = np.log(df['age'])
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output  age_square  age_cube   age_log
# ...

# %%
df['oldpeak_square']=np.square(df['oldpeak'])
df['oldpeak_cube']=np.power(df['oldpeak'],3)
df['oldpeak_log']=np.log(df['oldpeak'])
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# ...

# %%
df['thalachh'] = df['thalachh'].astype('object')
for i in range(len(df)):
  if df.loc[i, 'thalachh'] <= 100:
    df.loc[i, 'thalachh'] = 'Low'
  elif df.loc[i, 'thalachh'] <= 120:
    df.loc[i, 'thalachh'] = 'Mid'
  else:
    df.loc[i, 'thalachh'] = 'High'

df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0     High     0      2.3    0
# 1     37    1   2     130   250    0        1     High     0      3.5    0
# 2     41    0   1     130   204    0        0     High     0      1.4    2
# 3     56    1   1     120   236    0        1     High     0      0.8    2
# 4     57    0   0     120   354    0        1     High     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...      ...   ...      ...  ...
# 298   57    0   0     140   241    0        1     High     1      0.2    1
# 299   45    1   3     110   264    0        1     High     0      1.2    1
# 300   68    1   0     144   193    1        1     High     0      3.4    1
# 301   57    1   0     130   131    0        1      Mid     1      1.2    1
# 302   57    0   1     130   236    0        0     High     0      0.0    1
#
# ...

# %%
df['ChestPain'] = df['cp'].replace({'typical': 0, 'asymptomatic': 1, 'nonanginal': 2, 'nontypical': 3})

df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg thalachh  exng  oldpeak  ...  \
# 0     63    1   3     145   233    1        0     High     0      2.3  ...
# 1     37    1   2     130   250    0        1     High     0      3.5  ...
# 2     41    0   1     130   204    0        0     High     0      1.4  ...
# 3     56    1   1     120   236    0        1     High     0      0.8  ...
# 4     57    0   0     120   354    0        1     High     1      0.6  ...
# ..   ...  ...  ..     ...   ...  ...      ...      ...   ...      ...  ...
# 298   57    0   0     140   241    0        1     High     1      0.2  ...
# 299   45    1   3     110   264    0        1     High     0      1.2  ...
# 300   68    1   0     144   193    1        1     High     0      3.4  ...
# 301   57    1   0     130   131    0        1      Mid     1      1.2  ...
# 302   57    0   1     130   236    0        0     High     0      0.0  ...
#
# ...

# %% [markdown]
# Naive Baye's

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

X = df[['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'oldpeak']]
y = df['output']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)

y_pred = nb_classifier.predict(X_test)

accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8131868131868132

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)

y_pred_dt = dt_classifier.predict(X_test)

accuracy_dt = metrics.accuracy_score(y_test, y_pred_dt)
print("Accuracy (Decision Tree):", accuracy_dt)
# Out:
# Accuracy (Decision Tree): 0.7252747252747253

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier =RandomForestClassifier()
rf_classifier.fit(X_train, y_train)

y_pred_rf = rf_classifier.predict(X_test)

accuracy_rf = metrics.accuracy_score(y_test, y_pred_rf)
print("accuracy (random forest):", accuracy_rf)
# Out:
# accuracy (random forest): 0.8131868131868132

# %% [markdown]
# Error Correction

# %%
df['caa'].max()
# Out:
# 4

# %%
df['caa'] = df['caa'].replace(4, df['caa'].mean())

# %%
df['caa'].max()
# Out:
# 3.0

# %%
df['output'].max()
# Out:
# 1

# %%
df['slp'].max()
# Out:
# 2
