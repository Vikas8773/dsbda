# %%
import pandas as pd

# %%
df = pd.read_csv('facebook.csv',sep=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.loc[[0,5,3]]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 5            139441  Status         2          12             1          9
# 3            139441   Photo         2          12             2         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 5   0.0                      10472                            20849
# 3   1.0                      50128                            87991
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 5                    1191                     1073
# 3                    2211                      790
#
#    Lifetime Post Consumptions  \
# 0                         159
# 5                        1389
# 3                        1119
#
# ...

# %% [markdown]
# 1.subset

# %%
subset1=df.loc[df['comment']>=50]
subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 142            136013  Status         2          10             3          2
# 168            135428   Photo         1           9             3         10
# 228            131728   Photo         2           7             4          3
# 244            130791   Photo         2           7             3          5
# 288            126141   Photo         1           6             4         12
# 379            111620   Photo         3           4             1         14
# 460             92507   Photo         3           2             1         13
# 480             86909   Photo         2           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3     1.0                      50128                            87991
# ...

# %%
sub1=subset1[['Type','Category','like'] ]
sub1
# Out:
#        Type  Category    like
# 3     Photo         2  1572.0
# 142  Status         2   859.0
# 168   Photo         1  1622.0
# 228   Photo         2   367.0
# 244   Photo         2  5172.0
# 288   Photo         1   469.0
# 379   Photo         3  1998.0
# 460   Photo         3  1546.0
# 480   Photo         2   360.0

# %%
sub1.sort_values( by="like", ascending=True, kind="mergesort" )
# Out:
#        Type  Category    like
# 480   Photo         2   360.0
# 228   Photo         2   367.0
# 288   Photo         1   469.0
# 142  Status         2   859.0
# 460   Photo         3  1546.0
# 3     Photo         2  1572.0
# 168   Photo         1  1622.0
# 379   Photo         3  1998.0
# 244   Photo         2  5172.0

# %%
subset2=df.loc[df['share']>=110]
subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 105            137020   Photo         1          10             2          4
# 168            135428   Photo         1           9             3         10
# 183            134879   Video         1           9             2         10
# 244            130791   Photo         2           7             3          5
# 349            117764   Photo         3           5             5         13
# 371            113028  Status         2           4             6          3
# 379            111620   Photo         3           4             1         14
# 460             92507   Photo         3           2             1         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3     1.0                      50128                            87991
# ...

# %%
 sub2=subset2[['Post Month','Lifetime Post Consumptions','like','share'] ]
 sub2
# Out:
#      Post Month  Lifetime Post Consumptions    like  share
# 3            12                        1119  1572.0  147.0
# 105          10                        4782   955.0  139.0
# 168           9                        4074  1622.0  208.0
# 183           9                        3253   345.0  121.0
# 244           7                        6242  5172.0  790.0
# 349           5                        2718  1639.0  122.0
# 371           4                        6591   447.0  123.0
# 379           4                        3391  1998.0  128.0
# 460           2                        6624  1546.0  181.0

# %%
sp=pd.merge(sub1,sub2)
sp
# Out:
#     Type  Category    like  Post Month  Lifetime Post Consumptions  share
# 0  Photo         2  1572.0          12                        1119  147.0
# 1  Photo         1  1622.0           9                        4074  208.0
# 2  Photo         2  5172.0           7                        6242  790.0
# 3  Photo         3  1998.0           4                        3391  128.0
# 4  Photo         3  1546.0           2                        6624  181.0

# %%
sl=sp.T
sl
# Out:
#                                  0       1       2       3       4
# Type                         Photo   Photo   Photo   Photo   Photo
# Category                         2       1       2       3       3
# like                        1572.0  1622.0  5172.0  1998.0  1546.0
# Post Month                      12       9       7       4       2
# Lifetime Post Consumptions    1119    4074    6242    3391    6624
# share                        147.0   208.0   790.0   128.0   181.0

# %%
sp = sub1.join(sub2, how='inner', lsuffix='_sub1', rsuffix='_sub2')
sp
# Out:
#       Type  Category  like_sub1  Post Month  Lifetime Post Consumptions  \
# 3    Photo         2     1572.0          12                        1119
# 168  Photo         1     1622.0           9                        4074
# 244  Photo         2     5172.0           7                        6242
# 379  Photo         3     1998.0           4                        3391
# 460  Photo         3     1546.0           2                        6624
#
#      like_sub2  share
# 3       1572.0  147.0
# 168     1622.0  208.0
# 244     5172.0  790.0
# 379     1998.0  128.0
# 460     1546.0  181.0

# %%
sw = pd.concat([sub1, sub2])
sw
# Out:
#        Type  Category    like  Post Month  Lifetime Post Consumptions  share
# 3     Photo       2.0  1572.0         NaN                         NaN    NaN
# 142  Status       2.0   859.0         NaN                         NaN    NaN
# 168   Photo       1.0  1622.0         NaN                         NaN    NaN
# 228   Photo       2.0   367.0         NaN                         NaN    NaN
# 244   Photo       2.0  5172.0         NaN                         NaN    NaN
# 288   Photo       1.0   469.0         NaN                         NaN    NaN
# 379   Photo       3.0  1998.0         NaN                         NaN    NaN
# 460   Photo       3.0  1546.0         NaN                         NaN    NaN
# 480   Photo       2.0   360.0         NaN                         NaN    NaN
# 3       NaN       NaN  1572.0        12.0                      1119.0  147.0
# 105     NaN       NaN   955.0        10.0                      4782.0  139.0
# ...

# %%
sp.sort_values( by="Post Month", ascending=True, kind="quicksort")
# Out:
#       Type  Category  like_sub1  Post Month  Lifetime Post Consumptions  \
# 460  Photo         3     1546.0           2                        6624
# 379  Photo         3     1998.0           4                        3391
# 244  Photo         2     5172.0           7                        6242
# 168  Photo         1     1622.0           9                        4074
# 3    Photo         2     1572.0          12                        1119
#
#      like_sub2  share
# 460     1546.0  181.0
# 379     1998.0  128.0
# 244     5172.0  790.0
# 168     1622.0  208.0
# 3       1572.0  147.0

# %%
subset3=df.loc[df['comment']>=50]
subset3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 142            136013  Status         2          10             3          2
# 168            135428   Photo         1           9             3         10
# 228            131728   Photo         2           7             4          3
# 244            130791   Photo         2           7             3          5
# 288            126141   Photo         1           6             4         12
# 379            111620   Photo         3           4             1         14
# 460             92507   Photo         3           2             1         13
# 480             86909   Photo         2           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3     1.0                      50128                            87991
# ...

# %%
 sub3 =subset3[['Type','Category','share','comment'] ]
 sub3
# Out:
#        Type  Category  share  comment
# 3     Photo         2  147.0       58
# 142  Status         2   90.0       60
# 168   Photo         1  208.0      144
# 228   Photo         2   25.0       64
# 244   Photo         2  790.0      372
# 288   Photo         1   33.0      103
# 379   Photo         3  128.0       51
# 460   Photo         3  181.0      146
# 480   Photo         2   99.0       56

# %%
sub4=pd.melt(sub3, id_vars=['comment'],value_vars=['Type'])
sub4
# Out:
#    comment variable   value
# 0       58     Type   Photo
# 1       60     Type  Status
# 2      144     Type   Photo
# 3       64     Type   Photo
# 4      372     Type   Photo
# 5      103     Type   Photo
# 6       51     Type   Photo
# 7      146     Type   Photo
# 8       56     Type   Photo

# %%
sub5 = sub3.pivot(index='comment', columns='Type', values='share')
sub5
# Out:
# Type     Photo  Status
# comment
# 51       128.0     NaN
# 56        99.0     NaN
# 58       147.0     NaN
# 60         NaN    90.0
# 64        25.0     NaN
# 103       33.0     NaN
# 144      208.0     NaN
# 146      181.0     NaN
# 372      790.0     NaN
